# %% [markdown]
# # Audio splitter — chapter 1 (final stage)
#
# Take a canonical *raw* JSONL produced by some `prep_*.ipynb` and **cut the actual per-instance WAV files** referenced by every `audio_path`.
#
# **Input**
# - `data/processed_jsonl/<dataset>_instance.raw.jsonl` — every record's `audio_path` is a *predicted* future location (the file doesn't exist yet).
# - `data/unpacked/<dataset>/...` — the source WAVs the prep notebook referred to via `metadata.source_file`.
#
# **Output**
# - `data/cut_audio/<dataset>/...` — one 16 kHz mono PCM-16 WAV per record.
# - `data/processed_jsonl/<dataset>_instance.jsonl` — same content as the raw JSONL but with `audio_path` now pointing at files that exist.
#
# **What this notebook does NOT do**
# - Edit labels, splits, or text — that's the prep notebook's job.
# - Apply VAD, denoising, or any other DSP beyond resample-to-16k + trim.
# - Keep records whose source WAV can't be resolved. They get dropped. (No half-baked records in the output.)
#
# **Convention.** Every function in this notebook will eventually become a function in `audio_splitter.py`. For now, notebook-first.
#
# ---
#
# ## 0. Setup
#
# The only import we need from this project is `utils_dataprep` (canonical JSONL I/O, schema validation, path helpers). Everything else is in the cells below.

# %%
import sys
from pathlib import Path

# Make sure we can import utils_dataprep no matter where Jupyter was launched.
HERE = Path.cwd()
if HERE.name != "1_data_prep":
    candidate = HERE / "1_data_prep"
    if candidate.exists():
        HERE = candidate
sys.path.insert(0, str(HERE))

import utils_dataprep as udp

PROJECT_ROOT = udp.PROJECT_ROOT
print(f"PROJECT_ROOT = {PROJECT_ROOT}")
print(f"Chapter dir = {HERE}")
# Out:
# PROJECT_ROOT = /home/ivan/Posao_IJS/Stepping_Stones/github_full_repo/slavic-speech-pipeline
# Chapter dir = /home/ivan/Posao_IJS/Stepping_Stones/github_full_repo/slavic-speech-pipeline/1_data_prep

# %% [markdown]
# Standard third-party imports — already in `requirements.txt` / `setup_env.sh`.

# %%
from collections import OrderedDict
from dataclasses import dataclass

import numpy as np
import soundfile as sf
from tqdm.auto import tqdm

# %% [markdown]
# ---
#
# ## 1. Config
#
# All knobs are here. Edit, re-run the cells below.
#
# **Conventions**
# - All paths are project-relative strings.
# - `source_audio_root` is recursively scanned for `*.wav` files. Lookup happens by stem (e.g. `metadata.source_file="ROG-Dia-GSO-P0005.exb"` → stem `ROG-Dia-GSO-P0005` → match the WAV with that stem under the root).
# - `force=True` re-cuts existing destinations. Leave `False` for cheap re-runs.
# - `test_mode=True` processes the first `test_n` records and writes outputs to `data/test_processed_jsonl/` so production files are safe.

# %%
@dataclass
class Config:
    
    # # Input (a *.raw.jsonl produced by some prep_*.ipynb)
    # input_jsonl: str = "data/processed_jsonl/rog_dialog_instance.raw.jsonl"
    # # Output (canonical JSONL with audio_path pointing at real cut WAVs)
    # output_jsonl: str = "data/processed_jsonl/rog_dialog_instance.jsonl"
    # # Recursive root to scan for source WAVs. Anything below this with a .wav
    # # extension is added to the index; lookups are by stem.
    # source_audio_root: str = "data/unpacked/ROG-Dialog"
    # #TODO make like dicts for each dataset and just choose one or something - for instance only right?

    # Input (a *.raw.jsonl produced by some prep_*.ipynb)
    input_jsonl: str = "data/processed_jsonl/rog_instance.raw.jsonl"
    # Output (canonical JSONL with audio_path pointing at real cut WAVs)
    output_jsonl: str = "data/processed_jsonl/rog_instance.jsonl"
    # Recursive root to scan for source WAVs. Anything below this with a .wav
    # extension is added to the index; lookups are by stem.
    source_audio_root: str = "data/unpacked/ROG"




    # Re-cut destinations even if they already exist.
    force: bool = False
    # Warn (but keep) cuts shorter than this many ms. Set to 0 to silence.
    short_cut_warn_ms: int = 100
    # Cache up to this many source WAVs in memory. ROG-Dialog has hundreds of
    # segments per source, so even 1 is huge; 4 gives breathing room when
    # records aren't perfectly clustered by file_id.
    source_cache_size: int = 4

    # Test mode
    test_mode: bool = False                                                     ################ TEST MODE
    test_n: int = 10


cfg = Config()
print(cfg)
if cfg.test_mode:
    udp.banner("🧪 TEST MODE ENABLED", char="-")
# Out:
# Config(input_jsonl='data/processed_jsonl/rog_instance.raw.jsonl', output_jsonl='data/processed_jsonl/rog_instance.jsonl', source_audio_root='data/unpacked/ROG', force=False, short_cut_warn_ms=100, source_cache_size=4, test_mode=False, test_n=10)

# %% [markdown]
# ---
#
# ## 2. Source-WAV resolution
#
# We walk `source_audio_root` once, indexing every `.wav` by stem. Records are then resolved via `metadata.source_file` (set by the prep notebook), stripping its extension.
#
# Collisions — two WAVs with the same stem under different subfolders — are reported. First one wins; that's almost certainly a dataset-layout bug worth flagging.

# %%
def build_source_index(source_audio_root: str) -> dict[str, Path]:
    """Walk `source_audio_root` recursively, return {stem: absolute_wav_path}."""
    root = udp.from_project_relative(source_audio_root)
    if not root.exists():
        raise FileNotFoundError(
            f"source_audio_root does not exist: {root}\n"
            f"Set Config.source_audio_root."
        )

    index: dict[str, Path] = {}
    collisions: list[tuple[str, Path, Path]] = []
    for wav in root.rglob("*.wav"):
        stem = wav.stem
        if stem in index:
            collisions.append((stem, index[stem], wav))
            continue
        index[stem] = wav

    if collisions:
        print(f"⚠️  {len(collisions)} duplicate WAV stems under {root}; keeping the first:")
        for stem, kept, dropped in collisions[:5]:
            print(f"   - {stem}: kept {kept.relative_to(root)}, ignored {dropped.relative_to(root)}")
        if len(collisions) > 5:
            print(f"   ... and {len(collisions) - 5} more")

    return index


def resolve_source(record: dict, index: dict[str, Path]) -> Path | None:
    """
    Look up the source WAV for `record` in `index`. Returns absolute Path or None.

    Strategy: take `metadata.source_file` (the authoritative field set by the
    prep notebook), strip its extension, and look up by stem.
    """
    src_file = record.get("metadata", {}).get("source_file")
    if not src_file:
        return None
    stem = Path(src_file).stem  # "foo.exb" -> "foo"
    return index.get(stem)

# %% [markdown]
# ---
#
# ## 3. Audio I/O — the slim inner loop
#
# `SourceCache` is a tiny LRU that holds decoded source arrays. Without it, a 5-minute source WAV would be re-decoded for every one of its hundreds of segments. With it, each source is decoded exactly once.
#
# `cut_slice` is the hot path: take the cached array, slice in samples, resample to 16 kHz, write PCM-16.
#
# `cut_whole_file` handles the (chapter-4) case where there's no `start_t`/`end_t` — delegate to `udp.resample_to_16k_mono`.

# %%
class SourceCache:
    """Tiny LRU cache for decoded source WAVs (data, sr) keyed by absolute path."""

    def __init__(self, max_size: int = 4) -> None:
        self.max_size = max(1, int(max_size))
        self._cache: OrderedDict[str, tuple[np.ndarray, int]] = OrderedDict()

    def get(self, path: Path) -> tuple[np.ndarray, int]:
        key = str(path)
        if key in self._cache:
            self._cache.move_to_end(key)
            return self._cache[key]
        data, sr = sf.read(key, dtype="float32", always_2d=False)
        if data.ndim == 2:
            data = data.mean(axis=1)
        self._cache[key] = (data, sr)
        if len(self._cache) > self.max_size:
            self._cache.popitem(last=False)
        return data, sr


def _resample_array_to_16k(data: np.ndarray, sr: int) -> np.ndarray:
    """Resample a 1-D float32 array to 16 kHz. Prefer librosa; fall back to scipy."""
    if sr == 16000:
        return data
    try:
        import librosa
        return librosa.resample(data, orig_sr=sr, target_sr=16000)
    except ImportError:
        from math import gcd
        from scipy.signal import resample_poly
        g = gcd(sr, 16000)
        return resample_poly(data, 16000 // g, sr // g).astype(np.float32)


def cut_slice(record: dict, cache: SourceCache, src_path: Path, dst_path: Path) -> bool:
    """Slice [start_t, end_t] from cached source, resample to 16 kHz, write 16-bit PCM."""
    try:
        data, sr = cache.get(src_path)
        st = float(record["start_t"])
        et = float(record["end_t"])
        s = max(0, int(st * sr))
        e = min(len(data), int(et * sr))
        if e <= s:
            print(f"⚠️  {record['instance_id']}: end <= start after sample-conversion (s={s}, e={e}); dropping")
            return False
        clip = data[s:e]
        clip = _resample_array_to_16k(clip, sr)
        dst_path.parent.mkdir(parents=True, exist_ok=True)
        sf.write(str(dst_path), clip, 16000, subtype="PCM_16")
        return True
    except Exception as ex:
        print(f"⚠️  {record['instance_id']}: cut failed ({ex}); dropping")
        return False


def cut_whole_file(record: dict, src_path: Path, dst_path: Path) -> bool:
    """Whole-file copy + resample for records without start_t/end_t."""
    try:
        udp.resample_to_16k_mono(src_path, dst_path)
        return True
    except Exception as ex:
        print(f"⚠️  {record['instance_id']}: whole-file copy failed ({ex}); dropping")
        return False

# %% [markdown]
# ---
#
# ## 4. Main loop
#
# `process_records` orchestrates everything:
# 1. Sort records by source path so cache hits hard (all segments of one source processed back-to-back).
# 2. For each record: resolve source → check destination exists → cut → record outcome.
# 3. Records that can't be cut are dropped from `kept`. Reasons are counted in `stats`.

# %%
def process_records(records: list[dict], index: dict[str, Path], cfg: Config) -> tuple[list[dict], dict]:
    """Cut every record. Returns (kept_records, stats_dict)."""
    cache = SourceCache(max_size=cfg.source_cache_size)
    stats = {"input": len(records), "missing_source": 0, "cut_failed": 0,
             "skipped_existing": 0, "kept": 0, "short_warned": 0}

    # Sort by source path for cache locality. Records with no resolvable source
    # land at the front (sort key "") and get dropped immediately.
    def _src_key(r: dict) -> str:
        p = resolve_source(r, index)
        return str(p) if p else ""
    records = sorted(records, key=_src_key)

    pbar = tqdm(records, desc="Cutting", unit="rec")
    kept: list[dict] = []
    for rec in pbar:
        src = resolve_source(rec, index)
        if src is None:
            stats["missing_source"] += 1
            continue

        dst_abs = udp.from_project_relative(rec["audio_path"])

        # Idempotency
        if dst_abs.exists() and dst_abs.stat().st_size > 0 and not cfg.force:
            stats["skipped_existing"] += 1
            rec["audio_path"] = udp.to_project_relative(dst_abs)
            kept.append(rec)
            continue

        has_slice = "start_t" in rec and "end_t" in rec
        ok = cut_slice(rec, cache, src, dst_abs) if has_slice else cut_whole_file(rec, src, dst_abs)

        if not ok:
            stats["cut_failed"] += 1
            continue

        # Short-cut warning (after success)
        if has_slice and cfg.short_cut_warn_ms > 0:
            duration_ms = (float(rec["end_t"]) - float(rec["start_t"])) * 1000.0
            if duration_ms < cfg.short_cut_warn_ms:
                stats["short_warned"] += 1
                pbar.write(f"   short cut ({duration_ms:.1f} ms): {rec['instance_id']}")

        rec["audio_path"] = udp.to_project_relative(dst_abs)
        kept.append(rec)
        stats["kept"] += 1

    return kept, stats

# %% [markdown]
# ---
#
# ## 5. Load and validate the input JSONL
#
# Every line must already conform to the canonical schema. If anything is off, we want to know now — not three hours into a cutting run.

# %%
records = udp.read_jsonl(cfg.input_jsonl)
n_total, n_valid, errs = udp.validate_jsonl(records)
print(f"Loaded {n_total} records, {n_valid} valid.")
if errs:
    print("First errors:")
    for e in errs[:5]:
        print(f"   {e}")
    raise ValueError("input JSONL failed canonical-schema validation")

if cfg.test_mode:
    records = records[: cfg.test_n]
    print(f"🧪 capped to {len(records)} records")

# Peek at one
import json as _json
print("\nSample record:")
print(_json.dumps(records[0], ensure_ascii=False, indent=2)[:600])
# Out:
# Loaded 37036 records, 37036 valid.
#
# Sample record:
# {
#   "instance_id": "ROG-Art_Rog-Art-J-Gvecg-P500001_Artur-J-G3003_2082.198_2082.453",
#   "dataset": "ROG-Art",
#   "file_id": "Rog-Art-J-Gvecg-P500001",
#   "audio_path": "data/cut_audio/ROG-Art/Rog-Art-J-Gvecg-P500001_Artur-J-G3003_2082.198_2082.453.wav",
#   "split": "train",
#   "speaker": "Artur-J-G3003",
#   "start_t": 2082.198,
#   "end_t": 2082.453,
#   "text": "Drage",
#   "labels": {
#     "filled_pause_present": 0,
#     "disfluency_count": 0
#   },
#   "metadata": {
#     "source_file": "Rog-Art-J-Gvecg-P500001.exb",
#     "source_format": "EXB",
#     "subcorpus": "Artur-J",
#     "speaker_info": {
#       "sex": "m

# %% [markdown]
# ---
#
# ## 6. Build the source-WAV index and check coverage
#
# If coverage is <100%, look at the first few unresolved records and check:
# - Is `metadata.source_file` populated correctly by the prep notebook?
# - Did `download_data` actually unpack the audio archive (it can fail silently on the GOS restricted handle)?
# - Is `source_audio_root` pointed at the right place?

# %%
index = build_source_index(cfg.source_audio_root)
print(f"Source index: {len(index)} WAVs under {cfg.source_audio_root}")

resolved = 0
unresolved_samples = []
for r in records:
    if resolve_source(r, index) is not None:
        resolved += 1
    elif len(unresolved_samples) < 5:
        unresolved_samples.append(r)

print(f"Resolved: {resolved}/{len(records)} ({100 * resolved / max(1, len(records)):.1f}%)")
if unresolved_samples:
    print("\nFirst unresolved records (these will be dropped):")
    for r in unresolved_samples:
        print(f"   - {r['instance_id']}  source_file={r['metadata'].get('source_file')!r}")
# Out:
# Source index: 58 WAVs under data/unpacked/ROG
# Resolved: 37036/37036 (100.0%)

# %% [markdown]
# ---
#
# ## 7. Cut
#
# The hot loop. Sources cached, slices written, failures dropped.

# %%
kept, stats = process_records(records, index, cfg)
udp.banner("Stats", char="-")
for k, v in stats.items():
    print(f"  {k:>18}: {v}")
# Out:
# Cutting:   0%|          | 0/37036 [00:00<?, ?rec/s]
#    short cut (100.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500001_Artur-J-G3003_2135.742_2135.842
#    short cut (80.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500001_Artur-J-G3003_2163.863_2163.943
#    short cut (70.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500001_Artur-J-G3003_2163.943_2164.013
#    short cut (90.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500001_Artur-J-G3003_2164.623_2164.713
#    short cut (90.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500001_Artur-J-G3003_2172.863_2172.953
#    short cut (90.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500001_Artur-J-G3003_2208.219_2208.309
#    short cut (90.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500001_Artur-J-G3003_2227.346_2227.436
#    short cut (60.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500001_Artur-J-G3003_2229.428_2229.488
#    short cut (80.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500001_Artur-J-G3003_2279.088_2279.168
#    short cut (80.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500001_Artur-J-G3003_2297.124_2297.204
#    short cut (80.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500001_Artur-J-G3003_2341.928_2342.008
#    short cut (80.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500001_Artur-J-G3003_2348.665_2348.745
#    short cut (80.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500001_Artur-J-G3003_2391.677_2391.757
#    short cut (90.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500001_Artur-J-G3003_2391.757_2391.847
# ⚠️  ROG-Art_Rog-Art-J-Gvecg-P500001_Artur-J-G3003_2425.844_2425.844: end <= start after sample-conversion (s=106979720, e=106979720); dropping
#    short cut (100.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500001_Artur-J-G3003_2442.184_2442.284
#    short cut (60.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500001_Artur-J-G3003_2470.576_2470.636
#    short cut (90.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500001_Artur-J-G3003_2474.110_2474.200
#    short cut (100.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500001_Artur-J-G3003_2475.608_2475.708
#    short cut (90.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500001_Artur-J-G3003_2476.798_2476.888
#    short cut (70.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500001_Artur-J-G3003_2483.717_2483.787
#    short cut (57.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500001_Artur-J-G3003_2487.232_2487.289
#    short cut (90.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500002_Artur-J-G3002_9.526_9.616
#    short cut (100.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500002_Artur-J-G3002_9.616_9.716
#    short cut (95.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500002_Artur-J-G3002_19.941_20.036
#    short cut (65.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500002_Artur-J-G3002_89.085_89.150
#    short cut (85.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500002_Artur-J-G3002_200.404_200.489
#    short cut (65.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500002_Artur-J-G3002_206.054_206.119
#    short cut (80.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500002_Artur-J-G3002_212.875_212.955
#    short cut (84.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500002_Artur-J-G3002_230.035_230.119
#    short cut (85.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500002_Artur-J-G3002_248.789_248.874
#    short cut (93.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500002_Artur-J-G3002_282.627_282.720
#    short cut (76.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500002_Artur-J-G3002_297.199_297.275
#    short cut (65.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500002_Artur-J-G3002_338.496_338.561
#    short cut (65.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500002_Artur-J-G3002_391.496_391.561
#    short cut (60.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500014_Artur-J-G3020_581.993_582.053
#    short cut (90.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500014_Artur-J-G3020_583.083_583.173
#    short cut (80.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500014_Artur-J-G3020_594.924_595.004
#    short cut (60.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500014_Artur-J-G3020_620.410_620.470
#    short cut (90.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500014_Artur-J-G3020_636.108_636.198
#    short cut (90.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500014_Artur-J-G3020_642.834_642.924
#    short cut (80.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500014_Artur-J-G3020_644.717_644.797
#    short cut (80.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500014_Artur-J-G3020_647.187_647.267
#    short cut (60.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500014_Artur-J-G3020_680.204_680.264
#    short cut (84.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500014_Artur-J-G3020_701.473_701.557
#    short cut (60.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500014_Artur-J-G3020_711.461_711.521
#    short cut (80.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500014_Artur-J-G3020_716.480_716.560
#    short cut (77.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500014_Artur-J-G3020_724.880_724.957
#    short cut (70.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500014_Artur-J-G3020_730.723_730.793
#    short cut (70.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500014_Artur-J-G3020_734.400_734.470
#    short cut (80.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500014_Artur-J-G3020_743.723_743.803
#    short cut (73.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500014_Artur-J-G3020_757.840_757.913
#    short cut (80.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500014_Artur-J-G3020_764.258_764.338
#    short cut (80.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500014_Artur-J-G3020_766.749_766.829
# ⚠️  ROG-Art_Rog-Art-J-Gvecg-P500014_Artur-J-G3020_772.421_772.421: end <= start after sample-conversion (s=34063766, e=34063766); dropping
#    short cut (90.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500014_Artur-J-G3020_779.537_779.627
#    short cut (80.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500014_Artur-J-G3020_782.116_782.196
#    short cut (90.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500014_Artur-J-G3020_790.201_790.291
#    short cut (90.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500014_Artur-J-G3020_797.075_797.165
#    short cut (70.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500014_Artur-J-G3020_798.675_798.745
#    short cut (80.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500014_Artur-J-G3020_802.592_802.672
#    short cut (80.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500014_Artur-J-G3020_811.998_812.078
#    short cut (80.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500014_Artur-J-G3020_831.617_831.697
#    short cut (80.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500014_Artur-J-G3020_836.349_836.429
#    short cut (90.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500014_Artur-J-G3020_849.737_849.827
#    short cut (90.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500014_Artur-J-G3020_851.527_851.617
#    short cut (80.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500014_Artur-J-G3020_855.951_856.031
#    short cut (80.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500014_Artur-J-G3020_875.294_875.374
#    short cut (61.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500014_Artur-J-G3020_892.760_892.821
#    short cut (90.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500014_Artur-J-G3020_902.831_902.921
#    short cut (91.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500014_Artur-J-G3020_933.096_933.187
#    short cut (70.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500014_Artur-J-G3020_943.370_943.440
#    short cut (70.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500014_Artur-J-G3018_921.356_921.426
#    short cut (90.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500014_Artur-J-G3018_926.581_926.671
#    short cut (90.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500016_Artur-J-G3025_263.051_263.141
#    short cut (90.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500016_Artur-J-G3025_313.440_313.530
#    short cut (90.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500016_Artur-J-G3025_354.776_354.866
#    short cut (70.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500016_Artur-J-G3025_463.629_463.699
#    short cut (63.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500016_Artur-J-G3025_468.202_468.265
#    short cut (100.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500016_Artur-J-G3018_59.194_59.294
# ⚠️  ROG-Art_Rog-Art-J-Gvecg-P500016_Artur-J-G3018_61.052_61.052: end <= start after sample-conversion (s=2692393, e=2692393); dropping
# ⚠️  ROG-Art_Rog-Art-J-Gvecg-P500016_Artur-J-G3018_73.286_73.286: end <= start after sample-conversion (s=3231912, e=3231912); dropping
#    short cut (70.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500016_Artur-J-G3018_73.576_73.646
#    short cut (70.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500016_Artur-J-G3018_83.193_83.263
#    short cut (90.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500016_Artur-J-G3018_95.179_95.269
#    short cut (80.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500016_Artur-J-G3018_99.182_99.262
#    short cut (100.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500016_Artur-J-G3018_100.132_100.232
#    short cut (76.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500016_Artur-J-G3018_130.716_130.792
#    short cut (100.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500016_Artur-J-G3018_133.580_133.680
#    short cut (100.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500016_Artur-J-G3018_153.285_153.385
#    short cut (70.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500016_Artur-J-G3018_155.543_155.613
#    short cut (90.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500016_Artur-J-G3018_159.922_160.012
#    short cut (90.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500016_Artur-J-G3018_160.012_160.102
#    short cut (70.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500016_Artur-J-G3018_443.228_443.298
#    short cut (57.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500021_Artur-J-G3047_1.773_1.830
#    short cut (100.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500021_Artur-J-G3047_99.552_99.652
#    short cut (70.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500021_Artur-J-G3047_101.912_101.982
#    short cut (90.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500021_Artur-J-G3047_101.982_102.072
#    short cut (90.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500021_Artur-J-G3047_148.480_148.570
#    short cut (80.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500021_Artur-J-G3047_155.770_155.850
#    short cut (100.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500021_Artur-J-G3047_244.964_245.064
#    short cut (91.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500021_Artur-J-G3047_251.613_251.704
#    short cut (60.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500021_Artur-J-G3047_273.315_273.375
#    short cut (90.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500021_Artur-J-G3047_277.766_277.856
#    short cut (70.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500021_Artur-J-G3047_305.550_305.620
#    short cut (60.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500021_Artur-J-G3047_342.777_342.837
#    short cut (97.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500026_Artur-J-G3056_351.807_351.904
#    short cut (100.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500026_Artur-J-G3056_353.117_353.217
#    short cut (70.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500026_Artur-J-G3056_367.741_367.811
#    short cut (100.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500026_Artur-J-G3056_400.761_400.861
#    short cut (80.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500026_Artur-J-G3056_400.861_400.941
#    short cut (95.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500026_Artur-J-G3056_423.747_423.842
#    short cut (70.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500026_Artur-J-G3056_434.934_435.004
#    short cut (60.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500026_Artur-J-G3056_435.664_435.724
#    short cut (70.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500026_Artur-J-G3056_466.230_466.300
#    short cut (80.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500026_Artur-J-G3056_479.342_479.422
#    short cut (100.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500026_Artur-J-G3056_479.562_479.662
#    short cut (100.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500026_Artur-J-G3056_483.442_483.542
#    short cut (100.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500026_Artur-J-G3056_543.330_543.430
#    short cut (60.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500026_Artur-J-G3056_544.440_544.500
#    short cut (89.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500026_Artur-J-G3056_565.780_565.869
#    short cut (90.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500026_Artur-J-G3056_597.477_597.567
#    short cut (60.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500026_Artur-J-G3056_626.950_627.010
#    short cut (70.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500026_Artur-J-G3056_659.369_659.439
#    short cut (90.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500026_Artur-J-G3056_666.499_666.589
#    short cut (80.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500026_Artur-J-G3056_666.589_666.669
#    short cut (60.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500026_Artur-J-G3056_667.972_668.032
#    short cut (80.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500026_Artur-J-G3056_690.125_690.205
#    short cut (60.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500026_Artur-J-G3056_691.493_691.553
#    short cut (90.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500026_Artur-J-G3056_691.663_691.753
#    short cut (60.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500026_Artur-J-G3057_637.594_637.654
# ⚠️  ROG-Art_Rog-Art-J-Gvecg-P500026_Artur-J-G3055_695.391_695.391: end <= start after sample-conversion (s=30666743, e=30666743); dropping
#    short cut (60.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500026_Artur-J-G3055_698.656_698.716
#    short cut (70.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500026_Artur-J-G3055_701.096_701.166
#    short cut (80.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500026_Artur-J-G3055_701.166_701.246
#    short cut (90.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500026_Artur-J-G3055_703.291_703.381
#    short cut (90.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500026_Artur-J-G3055_718.501_718.591
#    short cut (90.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500028_Artur-J-G3062_560.754_560.844
#    short cut (60.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500028_Artur-J-G3062_571.383_571.443
#    short cut (60.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500028_Artur-J-G3062_573.483_573.543
#    short cut (70.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500028_Artur-J-G3062_580.639_580.709
#    short cut (80.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500028_Artur-J-G3062_582.179_582.259
#    short cut (100.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500028_Artur-J-G3062_582.589_582.689
#    short cut (90.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500028_Artur-J-G3062_585.908_585.998
#    short cut (90.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500028_Artur-J-G3062_610.753_610.843
#    short cut (60.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500028_Artur-J-G3062_615.103_615.163
#    short cut (90.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500028_Artur-J-G3062_616.413_616.503
#    short cut (90.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500028_Artur-J-G3062_620.410_620.500
#    short cut (80.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500028_Artur-J-G3062_623.860_623.940
#    short cut (80.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500028_Artur-J-G3062_623.940_624.020
#    short cut (80.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500028_Artur-J-G3062_639.340_639.420
#    short cut (90.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500028_Artur-J-G3062_690.507_690.597
#    short cut (90.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500028_Artur-J-G3062_692.237_692.327
#    short cut (80.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500028_Artur-J-G3062_695.474_695.554
#    short cut (79.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500028_Artur-J-G3062_716.953_717.032
#    short cut (80.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500028_Artur-J-G3062_717.612_717.692
#    short cut (90.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500028_Artur-J-G3063_343.078_343.168
#    short cut (80.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500028_Artur-J-G3063_351.402_351.482
#    short cut (57.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500028_Artur-J-G3063_382.209_382.266
#    short cut (80.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500028_Artur-J-G3063_382.266_382.346
#    short cut (91.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500028_Artur-J-G3063_383.409_383.500
#    short cut (60.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500028_Artur-J-G3063_446.343_446.403
#    short cut (60.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500028_Artur-J-G3063_446.403_446.463
#    short cut (66.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500028_Artur-J-G3063_451.567_451.633
#    short cut (100.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500028_Artur-J-G3063_479.759_479.859
#    short cut (80.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500028_Artur-J-G3063_481.019_481.099
#    short cut (67.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500028_Artur-J-G3063_509.813_509.880
#    short cut (93.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500028_Artur-J-G3063_527.194_527.287
#    short cut (60.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500028_Artur-J-G3063_527.287_527.347
#    short cut (60.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500028_Artur-J-G3063_527.347_527.407
#    short cut (70.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500028_Artur-J-G3063_530.833_530.903
#    short cut (80.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500034_Artur-J-G3069_17.186_17.266
#    short cut (90.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500034_Artur-J-G3069_35.687_35.777
#    short cut (90.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500034_Artur-J-G3069_45.821_45.911
#    short cut (90.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500034_Artur-J-G3069_51.254_51.344
#    short cut (80.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500034_Artur-J-G3069_87.772_87.852
#    short cut (70.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500034_Artur-J-G3069_114.753_114.823
#    short cut (90.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500034_Artur-J-G3069_117.523_117.613
#    short cut (80.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500034_Artur-J-G3069_140.767_140.847
#    short cut (70.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500034_Artur-J-G3069_144.895_144.965
#    short cut (70.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500034_Artur-J-G3069_175.201_175.271
#    short cut (69.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500034_Artur-J-G3069_191.773_191.842
#    short cut (7.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500034_Artur-J-G3069_215.373_215.380
#    short cut (70.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500034_Artur-J-G3069_228.457_228.527
#    short cut (90.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500034_Artur-J-G3069_240.268_240.358
#    short cut (70.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500034_Artur-J-G3069_251.620_251.690
#    short cut (70.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500034_Artur-J-G3069_291.622_291.692
#    short cut (90.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500034_Artur-J-G3069_327.663_327.753
#    short cut (90.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500034_Artur-J-G3069_331.966_332.056
#    short cut (60.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500034_Artur-J-G3069_397.170_397.230
#    short cut (80.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500034_Artur-J-G3069_401.029_401.109
#    short cut (70.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500034_Artur-J-G3069_406.494_406.564
#    short cut (70.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500034_Artur-J-G3069_407.044_407.114
#    short cut (70.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500034_Artur-J-G3069_407.114_407.184
#    short cut (90.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500037_Artur-J-G3070_15.518_15.608
#    short cut (90.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500037_Artur-J-G3070_18.633_18.723
#    short cut (60.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500037_Artur-J-G3070_24.341_24.401
#    short cut (60.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500037_Artur-J-G3070_36.421_36.481
#    short cut (80.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500037_Artur-J-G3070_39.544_39.624
#    short cut (90.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500037_Artur-J-G3070_40.934_41.024
#    short cut (90.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500037_Artur-J-G3070_43.413_43.503
#    short cut (80.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500037_Artur-J-G3070_47.428_47.508
#    short cut (60.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500037_Artur-J-G3070_56.258_56.318
#    short cut (98.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500037_Artur-J-G3070_69.468_69.566
#    short cut (100.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500037_Artur-J-G3070_96.897_96.997
#    short cut (98.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500037_Artur-J-G3070_114.716_114.814
#    short cut (95.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500037_Artur-J-G3070_123.463_123.558
#    short cut (100.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500037_Artur-J-G3070_138.800_138.900
#    short cut (90.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500037_Artur-J-G3070_165.866_165.956
#    short cut (90.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500037_Artur-J-G3070_176.951_177.041
#    short cut (100.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500037_Artur-J-G3070_218.262_218.362
#    short cut (61.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500037_Artur-J-G3070_222.985_223.046
#    short cut (90.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500037_Artur-J-G3070_250.711_250.801
#    short cut (90.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500037_Artur-J-G3070_253.326_253.416
#    short cut (100.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500037_Artur-J-G3070_260.004_260.104
#    short cut (80.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500037_Artur-J-G3070_299.538_299.618
#    short cut (100.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500037_Artur-J-G3070_302.228_302.328
#    short cut (90.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500037_Artur-J-G3070_348.591_348.681
#    short cut (80.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500037_Artur-J-G3070_389.010_389.090
#    short cut (81.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500042_Artur-J-G3082_160.419_160.500
#    short cut (80.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500042_Artur-J-G3082_160.500_160.580
#    short cut (100.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500042_Artur-J-G3082_161.439_161.539
#    short cut (72.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500042_Artur-J-G3082_163.147_163.219
#    short cut (100.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500042_Artur-J-G3082_165.469_165.569
#    short cut (90.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500042_Artur-J-G3082_169.517_169.607
#    short cut (80.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500042_Artur-J-G3082_169.607_169.687
#    short cut (80.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500042_Artur-J-G3082_173.313_173.393
#    short cut (100.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500042_Artur-J-G3082_175.383_175.483
#    short cut (100.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500042_Artur-J-G3082_177.100_177.200
#    short cut (90.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500042_Artur-J-G3082_185.418_185.508
#    short cut (100.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500042_Artur-J-G3082_187.501_187.601
#    short cut (90.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500042_Artur-J-G3082_192.304_192.394
#    short cut (80.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500042_Artur-J-G3082_194.976_195.056
#    short cut (90.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500042_Artur-J-G3082_203.762_203.852
#    short cut (90.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500042_Artur-J-G3082_207.212_207.302
#    short cut (90.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500042_Artur-J-G3082_210.624_210.714
#    short cut (60.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500042_Artur-J-G3082_217.768_217.828
#    short cut (90.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500042_Artur-J-G3082_219.848_219.938
#    short cut (90.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500042_Artur-J-G3082_237.834_237.924
#    short cut (100.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500042_Artur-J-G3082_238.114_238.214
#    short cut (90.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500042_Artur-J-G3082_240.624_240.714
#    short cut (80.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500042_Artur-J-G3082_242.164_242.244
#    short cut (80.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500042_Artur-J-G3082_250.426_250.506
#    short cut (100.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500042_Artur-J-G3082_253.856_253.956
#    short cut (70.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500042_Artur-J-G3082_253.956_254.026
#    short cut (90.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500042_Artur-J-G3082_261.060_261.150
#    short cut (100.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500042_Artur-J-G3082_265.805_265.905
#    short cut (100.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500042_Artur-J-G3082_278.401_278.501
#    short cut (70.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500042_Artur-J-G3082_278.501_278.571
#    short cut (90.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500042_Artur-J-G3082_284.545_284.635
#    short cut (60.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500042_Artur-J-G3082_285.455_285.515
#    short cut (90.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500042_Artur-J-G3082_289.311_289.401
#    short cut (90.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500042_Artur-J-G3082_289.761_289.851
#    short cut (60.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500042_Artur-J-G3082_289.851_289.911
#    short cut (60.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500042_Artur-J-G3082_292.738_292.798
#    short cut (70.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500042_Artur-J-G3082_292.798_292.868
#    short cut (80.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500042_Artur-J-G3082_295.551_295.631
#    short cut (80.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500042_Artur-J-G3082_299.395_299.475
#    short cut (80.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500042_Artur-J-G3082_301.434_301.514
#    short cut (90.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500042_Artur-J-G3082_305.436_305.526
#    short cut (90.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500042_Artur-J-G3082_308.081_308.171
#    short cut (90.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500042_Artur-J-G3082_308.271_308.361
#    short cut (70.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500042_Artur-J-G3082_313.624_313.694
#    short cut (80.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500042_Artur-J-G3082_315.494_315.574
#    short cut (60.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500042_Artur-J-G3082_326.048_326.108
#    short cut (60.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500042_Artur-J-G3082_328.726_328.786
#    short cut (100.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500042_Artur-J-G3082_333.533_333.633
#    short cut (67.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500042_Artur-J-G3082_340.120_340.187
#    short cut (86.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500042_Artur-J-G3082_340.187_340.273
#    short cut (86.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500042_Artur-J-G3082_341.187_341.273
#    short cut (60.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500042_Artur-J-G3082_355.653_355.713
#    short cut (90.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500042_Artur-J-G3082_376.365_376.455
#    short cut (89.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500042_Artur-J-G3082_378.767_378.856
#    short cut (90.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500042_Artur-J-G3082_382.132_382.222
#    short cut (60.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500042_Artur-J-G3082_382.222_382.282
#    short cut (80.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500042_Artur-J-G3082_397.736_397.816
#    short cut (100.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500042_Artur-J-G3082_399.963_400.063
#    short cut (60.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500042_Artur-J-G3082_400.063_400.123
#    short cut (80.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500042_Artur-J-G3082_405.055_405.135
#    short cut (90.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500042_Artur-J-G3082_407.411_407.501
#    short cut (90.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500042_Artur-J-G3082_409.161_409.251
#    short cut (90.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500042_Artur-J-G3082_409.391_409.481
#    short cut (90.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500042_Artur-J-G3082_416.532_416.622
#    short cut (70.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500042_Artur-J-G3082_416.862_416.932
#    short cut (90.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500042_Artur-J-G3082_422.415_422.505
#    short cut (80.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500042_Artur-J-G3082_429.578_429.658
#    short cut (90.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500042_Artur-J-G3082_437.332_437.422
#    short cut (70.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500042_Artur-J-G3082_437.592_437.662
#    short cut (90.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500042_Artur-J-G3082_440.914_441.004
#    short cut (60.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500042_Artur-J-G3082_442.204_442.264
#    short cut (80.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500046_Artur-J-G3018_829.065_829.145
#    short cut (90.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500046_Artur-J-G3018_839.677_839.767
#    short cut (60.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500046_Artur-J-G3091_629.794_629.854
#    short cut (70.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500046_Artur-J-G3091_640.404_640.474
#    short cut (80.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500046_Artur-J-G3091_660.880_660.960
#    short cut (60.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500046_Artur-J-G3091_660.960_661.020
#    short cut (70.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500046_Artur-J-G3091_680.965_681.035
#    short cut (90.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500046_Artur-J-G3091_684.011_684.101
#    short cut (60.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500046_Artur-J-G3091_688.448_688.508
#    short cut (90.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500046_Artur-J-G3091_701.125_701.215
#    short cut (90.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500046_Artur-J-G3091_701.215_701.305
#    short cut (60.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500046_Artur-J-G3091_703.535_703.595
#    short cut (90.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500046_Artur-J-G3091_704.085_704.175
#    short cut (100.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500046_Artur-J-G3091_708.690_708.790
#    short cut (89.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500046_Artur-J-G3091_724.680_724.769
#    short cut (90.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500046_Artur-J-G3091_730.886_730.976
#    short cut (90.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500046_Artur-J-G3091_771.606_771.696
#    short cut (60.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500046_Artur-J-G3091_772.286_772.346
#    short cut (80.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500046_Artur-J-G3091_800.792_800.872
#    short cut (90.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500046_Artur-J-G3091_800.872_800.962
#    short cut (60.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500046_Artur-J-G3091_801.482_801.542
#    short cut (80.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500046_Artur-J-G3091_801.542_801.622
#    short cut (100.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500046_Artur-J-G3090_882.897_882.997
#    short cut (70.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500046_Artur-J-G3090_886.397_886.467
#    short cut (90.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500046_Artur-J-G3090_887.127_887.217
#    short cut (80.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500046_Artur-J-G3090_907.414_907.494
#    short cut (80.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500046_Artur-J-G3090_908.304_908.384
#    short cut (90.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500046_Artur-J-G3090_916.117_916.207
#    short cut (80.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500046_Artur-J-G3090_916.567_916.647
#    short cut (70.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500046_Artur-J-G3090_920.940_921.010
#    short cut (70.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500046_Artur-J-G3090_927.635_927.705
#    short cut (80.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500046_Artur-J-G3090_945.620_945.700
#    short cut (100.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500046_Artur-J-G3090_950.642_950.742
#    short cut (90.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500046_Artur-J-G3090_958.421_958.511
#    short cut (80.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500048_Artur-J-G3097_84.551_84.631
#    short cut (80.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500048_Artur-J-G3097_94.083_94.163
#    short cut (70.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500048_Artur-J-G3097_101.915_101.985
#    short cut (80.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500048_Artur-J-G3097_125.863_125.943
#    short cut (60.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500048_Artur-J-G3097_131.023_131.083
#    short cut (90.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500048_Artur-J-G3023_147.852_147.942
#    short cut (90.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500048_Artur-J-G3023_171.704_171.794
#    short cut (80.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500048_Artur-J-G3023_206.936_207.016
#    short cut (70.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500048_Artur-J-G3023_295.023_295.093
#    short cut (60.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500048_Artur-J-G3023_303.482_303.542
#    short cut (100.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500048_Artur-J-G3023_361.511_361.611
#    short cut (70.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500048_Artur-J-G3023_365.491_365.561
#    short cut (70.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500048_Artur-J-G3023_366.171_366.241
#    short cut (100.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500048_Artur-J-G3023_367.331_367.431
#    short cut (100.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500048_Artur-J-G3023_378.896_378.996
#    short cut (90.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500048_Artur-J-G3023_393.316_393.406
#    short cut (60.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500048_Artur-J-G3098_32.244_32.304
#    short cut (60.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500048_Artur-J-G3098_32.304_32.364
#    short cut (80.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500051_Artur-J-G3016_19.463_19.543
#    short cut (90.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500051_Artur-J-G3016_19.543_19.633
#    short cut (100.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500051_Artur-J-G3016_30.132_30.232
#    short cut (70.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500051_Artur-J-G3016_39.820_39.890
#    short cut (100.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500051_Artur-J-G3016_61.904_62.004
#    short cut (90.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500051_Artur-J-G3016_62.004_62.094
#    short cut (60.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500051_Artur-J-G3016_65.933_65.993
#    short cut (70.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500051_Artur-J-G3016_68.773_68.843
#    short cut (60.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500051_Artur-J-G3016_79.015_79.075
#    short cut (80.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500051_Artur-J-G3016_95.265_95.345
#    short cut (60.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500051_Artur-J-G3016_110.187_110.247
#    short cut (60.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500051_Artur-J-G3016_126.576_126.636
#    short cut (60.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500051_Artur-J-G3016_133.543_133.603
#    short cut (60.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500051_Artur-J-G3016_137.060_137.120
#    short cut (70.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500051_Artur-J-G3016_145.431_145.501
#    short cut (60.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500051_Artur-J-G3016_145.501_145.561
#    short cut (60.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500051_Artur-J-G3016_170.691_170.751
#    short cut (90.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500051_Artur-J-G3016_184.604_184.694
#    short cut (60.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500051_Artur-J-G3016_187.835_187.895
#    short cut (100.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500051_Artur-J-G3016_187.895_187.995
#    short cut (60.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500051_Artur-J-G3016_191.127_191.187
#    short cut (70.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500051_Artur-J-G3016_192.187_192.257
#    short cut (60.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500051_Artur-J-G3016_200.187_200.247
#    short cut (81.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500051_Artur-J-G3016_207.732_207.813
#    short cut (60.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500051_Artur-J-G3016_209.768_209.828
#    short cut (80.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500051_Artur-J-G3016_230.416_230.496
#    short cut (100.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500051_Artur-J-G3016_232.239_232.339
#    short cut (100.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500051_Artur-J-G3016_234.479_234.579
#    short cut (90.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500051_Artur-J-G3016_247.036_247.126
#    short cut (70.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500051_Artur-J-G3016_265.443_265.513
#    short cut (60.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500051_Artur-J-G3016_265.513_265.573
#    short cut (80.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500051_Artur-J-G3016_269.015_269.095
#    short cut (70.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500051_Artur-J-G3016_283.219_283.289
#    short cut (63.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500051_Artur-J-G3016_283.419_283.482
#    short cut (80.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500051_Artur-J-G3016_287.408_287.488
#    short cut (60.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500051_Artur-J-G3016_287.488_287.548
#    short cut (80.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500051_Artur-J-G3016_287.938_288.018
#    short cut (90.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500051_Artur-J-G3016_292.148_292.238
#    short cut (60.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500051_Artur-J-G3016_294.600_294.660
#    short cut (90.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500051_Artur-J-G3016_316.768_316.858
#    short cut (70.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500051_Artur-J-G3016_323.315_323.385
#    short cut (70.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500051_Artur-J-G3016_326.149_326.219
#    short cut (60.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500051_Artur-J-G3016_326.219_326.279
#    short cut (100.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500051_Artur-J-G3016_342.009_342.109
#    short cut (90.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500051_Artur-J-G3016_342.249_342.339
#    short cut (90.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500051_Artur-J-G3016_343.299_343.389
#    short cut (60.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500051_Artur-J-G3016_344.699_344.759
#    short cut (100.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500051_Artur-J-G3016_349.081_349.181
#    short cut (80.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500051_Artur-J-G3016_355.002_355.082
#    short cut (80.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500051_Artur-J-G3016_356.903_356.983
#    short cut (80.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500051_Artur-J-G3016_361.885_361.965
#    short cut (60.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500051_Artur-J-G3016_361.965_362.025
#    short cut (90.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500051_Artur-J-G3016_362.425_362.515
#    short cut (90.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500051_Artur-J-G3016_365.872_365.962
#    short cut (86.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500054_Artur-J-G3110_75.739_75.825
#    short cut (99.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500054_Artur-J-G3110_121.674_121.773
#    short cut (91.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500054_Artur-J-G3110_121.773_121.864
#    short cut (90.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500054_Artur-J-G3110_145.741_145.831
#    short cut (80.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500054_Artur-J-G3110_177.282_177.362
#    short cut (80.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500054_Artur-J-G3110_177.362_177.442
#    short cut (100.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500054_Artur-J-G3110_191.841_191.941
#    short cut (60.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500054_Artur-J-G3110_191.941_192.001
#    short cut (80.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500054_Artur-J-G3110_258.591_258.671
#    short cut (90.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500054_Artur-J-G3110_322.853_322.943
#    short cut (80.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500054_Artur-J-G3110_325.562_325.642
#    short cut (90.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500054_Artur-J-G3110_325.642_325.732
#    short cut (100.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500054_Artur-J-G3110_331.478_331.578
#    short cut (80.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500054_Artur-J-G3110_354.940_355.020
#    short cut (70.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500054_Artur-J-G3110_355.020_355.090
#    short cut (60.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500054_Artur-J-G3109_369.631_369.691
#    short cut (60.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500054_Artur-J-G3109_369.691_369.751
#    short cut (90.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500054_Artur-J-G3109_380.492_380.582
#    short cut (100.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500054_Artur-J-G3109_382.172_382.272
#    short cut (90.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500054_Artur-J-G3109_392.219_392.309
#    short cut (90.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500054_Artur-J-G3109_394.119_394.209
#    short cut (60.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500054_Artur-J-G3109_406.568_406.628
#    short cut (90.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500054_Artur-J-G3109_409.238_409.328
#    short cut (90.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500054_Artur-J-G3109_410.378_410.468
#    short cut (90.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500054_Artur-J-G3109_418.445_418.535
#    short cut (100.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500054_Artur-J-G3109_418.535_418.635
#    short cut (80.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500054_Artur-J-G3109_432.583_432.663
#    short cut (80.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500054_Artur-J-G3109_433.153_433.233
#    short cut (60.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500063_Artur-J-G3134_625.133_625.193
#    short cut (90.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500063_Artur-J-G3134_647.896_647.986
#    short cut (90.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500063_Artur-J-G3134_682.836_682.926
#    short cut (94.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500063_Artur-J-G3134_689.021_689.115
#    short cut (80.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500063_Artur-J-G3134_708.890_708.970
#    short cut (90.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500063_Artur-J-G3134_730.571_730.661
#    short cut (70.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500063_Artur-J-G3134_730.661_730.731
#    short cut (70.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500063_Artur-J-G3134_730.731_730.801
#    short cut (80.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500063_Artur-J-G3134_736.732_736.812
#    short cut (70.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500063_Artur-J-G3134_736.912_736.982
#    short cut (80.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500063_Artur-J-G3134_763.201_763.281
#    short cut (80.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500063_Artur-J-G3134_773.306_773.386
#    short cut (80.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500063_Artur-J-G3134_779.204_779.284
#    short cut (90.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500063_Artur-J-G3134_790.744_790.834
#    short cut (60.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500063_Artur-J-G3134_790.834_790.894
#    short cut (60.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500063_Artur-J-G3133_398.657_398.717
#    short cut (60.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500063_Artur-J-G3133_409.869_409.929
#    short cut (90.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500063_Artur-J-G3133_433.870_433.960
#    short cut (90.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500063_Artur-J-G3133_471.291_471.381
#    short cut (80.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500063_Artur-J-G3133_519.899_519.979
#    short cut (90.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500063_Artur-J-G3133_606.830_606.920
#    short cut (80.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500063_Artur-J-G3133_616.467_616.547
#    short cut (90.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500064_Artur-J-G3137_1578.696_1578.786
#    short cut (70.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500064_Artur-J-G3137_1607.465_1607.535
#    short cut (90.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500064_Artur-J-G3137_1616.110_1616.200
#    short cut (60.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500064_Artur-J-G3137_1625.946_1626.006
#    short cut (100.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500064_Artur-J-G3137_1642.806_1642.906
#    short cut (90.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500064_Artur-J-G3137_1655.246_1655.336
#    short cut (90.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500064_Artur-J-G3137_1662.280_1662.370
#    short cut (70.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500064_Artur-J-G3137_1678.116_1678.186
#    short cut (90.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500064_Artur-J-G3137_1701.720_1701.810
#    short cut (80.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500064_Artur-J-G3137_1721.151_1721.231
#    short cut (80.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500064_Artur-J-G3137_1740.128_1740.208
#    short cut (100.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500064_Artur-J-G3137_1743.068_1743.168
#    short cut (80.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500064_Artur-J-G3137_1748.214_1748.294
#    short cut (70.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500064_Artur-J-G3137_1758.197_1758.267
#    short cut (100.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500064_Artur-J-G3137_1815.423_1815.523
#    short cut (80.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500064_Artur-J-G3137_1816.153_1816.233
#    short cut (100.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500064_Artur-J-G3137_1851.189_1851.289
#    short cut (90.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500064_Artur-J-G3137_1855.979_1856.069
#    short cut (100.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500064_Artur-J-G3137_1875.299_1875.399
#    short cut (90.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500064_Artur-J-G3137_1877.240_1877.330
#    short cut (60.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500064_Artur-J-G3137_1889.058_1889.118
#    short cut (80.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500064_Artur-J-G3137_1906.758_1906.838
#    short cut (90.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500064_Artur-J-G3139_1680.892_1680.982
#    short cut (100.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500064_Artur-J-G3139_1684.202_1684.302
#    short cut (100.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500064_Artur-J-G3139_1768.547_1768.647
#    short cut (60.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500064_Artur-J-G3139_1785.348_1785.408
#    short cut (90.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500064_Artur-J-G3139_1786.438_1786.528
#    short cut (80.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500064_Artur-J-G3139_1794.030_1794.110
#    short cut (100.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500064_Artur-J-G3139_1799.288_1799.388
#    short cut (100.0 ms): ROG-Art_Rog-Art-J-Gvecg-P500064_Artur-J-G3139_1806.198_1806.298
#    short cut (100.0 ms): ROG-Art_Rog-Art-J-Gvecg-P580002_Artur-J-G4528_63.840_63.940
#    short cut (60.0 ms): ROG-Art_Rog-Art-J-Gvecg-P580002_Artur-J-G4528_117.683_117.743
#    short cut (90.0 ms): ROG-Art_Rog-Art-J-Gvecg-P580002_Artur-J-G4528_126.813_126.903
#    short cut (100.0 ms): ROG-Art_Rog-Art-J-Gvecg-P580002_Artur-J-G4528_159.583_159.683
#    short cut (100.0 ms): ROG-Art_Rog-Art-J-Gvecg-P580002_Artur-J-G4528_279.639_279.739
#    short cut (90.0 ms): ROG-Art_Rog-Art-J-Gvecg-P580002_Artur-J-G4528_326.625_326.715
#    short cut (80.0 ms): ROG-Art_Rog-Art-J-Gvecg-P580002_Artur-J-G4528_364.694_364.774
#    short cut (70.0 ms): ROG-Art_Rog-Art-J-Gvecg-P580002_Artur-J-G4528_364.774_364.844
#    short cut (100.0 ms): ROG-Art_Rog-Art-J-Gvecg-P580002_Artur-J-G4528_369.458_369.558
#    short cut (100.0 ms): ROG-Art_Rog-Art-J-Gvecg-P580002_Artur-J-G4528_379.115_379.215
#    short cut (80.0 ms): ROG-Art_Rog-Art-J-Gvecg-P580002_Artur-J-G4529_15.753_15.833
#    short cut (100.0 ms): ROG-Art_Rog-Art-J-Gvecg-P580002_Artur-J-G4529_17.533_17.633
#    short cut (90.0 ms): ROG-Art_Rog-Art-J-Gvecg-P580002_Artur-J-G4529_89.339_89.429
#    short cut (100.0 ms): ROG-Art_Rog-Art-J-Gvecg-P580002_Artur-J-G4529_89.599_89.699
#    short cut (80.0 ms): ROG-Art_Rog-Art-J-Gvecg-P580002_Artur-J-G4529_103.895_103.975
#    short cut (90.0 ms): ROG-Art_Rog-Art-J-Gvecg-P580002_Artur-J-G4529_178.932_179.022
#    short cut (80.0 ms): ROG-Art_Rog-Art-J-Gvecg-P580002_Artur-J-G4529_188.810_188.890
#    short cut (80.0 ms): ROG-Art_Rog-Art-J-Gvecg-P580002_Artur-J-G4529_324.292_324.372
#    short cut (66.0 ms): ROG-Art_Rog-Art-J-Gvecg-P580002_Artur-J-G4529_325.800_325.866
#    short cut (90.0 ms): ROG-Art_Rog-Art-J-Gvecg-P580003_Artur-J-G4531_4.380_4.470
#    short cut (60.0 ms): ROG-Art_Rog-Art-J-Gvecg-P580003_Artur-J-G4531_5.940_6.000
#    short cut (90.0 ms): ROG-Art_Rog-Art-J-Gvecg-P580003_Artur-J-G4531_14.267_14.357
# ⚠️  ROG-Art_Rog-Art-J-Gvecg-P580003_Artur-J-G4531_207.100_207.100: end <= start after sample-conversion (s=9133110, e=9133110); dropping
#    short cut (60.0 ms): ROG-Art_Rog-Art-J-Gvecg-P580003_Artur-J-G4531_230.467_230.527
#    short cut (60.0 ms): ROG-Art_Rog-Art-J-Gvecg-P580003_Artur-J-G4531_245.274_245.334
#    short cut (70.0 ms): ROG-Art_Rog-Art-J-Gvecg-P580003_Artur-J-G4531_292.011_292.081
#    short cut (60.0 ms): ROG-Art_Rog-Art-J-Gvecg-P580003_Artur-J-G4531_294.491_294.551
#    short cut (90.0 ms): ROG-Art_Rog-Art-J-Gvecg-P580003_Artur-J-G4531_295.391_295.481
#    short cut (60.0 ms): ROG-Art_Rog-Art-J-Gvecg-P580003_Artur-J-G4531_312.916_312.976
#    short cut (90.0 ms): ROG-Art_Rog-Art-J-Gvecg-P580003_Artur-J-G4530_41.584_41.674
#    short cut (60.0 ms): ROG-Art_Rog-Art-J-Gvecg-P580003_Artur-J-G4530_49.952_50.012
#    short cut (82.0 ms): ROG-Art_Rog-Art-J-Gvecg-P580003_Artur-J-G4530_74.200_74.282
#    short cut (70.0 ms): ROG-Art_Rog-Art-J-Gvecg-P580003_Artur-J-G4530_78.010_78.080
#    short cut (100.0 ms): ROG-Art_Rog-Art-J-Gvecg-P580003_Artur-J-G4530_79.930_80.030
#    short cut (100.0 ms): ROG-Art_Rog-Art-J-Gvecg-P580003_Artur-J-G4530_86.677_86.777
#    short cut (70.0 ms): ROG-Art_Rog-Art-J-Gvecg-P580003_Artur-J-G4530_95.304_95.374
#    short cut (70.0 ms): ROG-Art_Rog-Art-J-Gvecg-P580003_Artur-J-G4530_99.048_99.118
#    short cut (90.0 ms): ROG-Art_Rog-Art-J-Gvecg-P580003_Artur-J-G4530_103.161_103.251
#    short cut (100.0 ms): ROG-Art_Rog-Art-J-Gvecg-P580003_Artur-J-G4530_110.244_110.344
#    short cut (100.0 ms): ROG-Art_Rog-Art-J-Gvecg-P580003_Artur-J-G4530_113.224_113.324
#    short cut (60.0 ms): ROG-Art_Rog-Art-J-Gvecg-P580003_Artur-J-G4530_120.253_120.313
#    short cut (90.0 ms): ROG-Art_Rog-Art-J-Gvecg-P580003_Artur-J-G4530_122.543_122.633
#    short cut (70.0 ms): ROG-Art_Rog-Art-J-Gvecg-P580003_Artur-J-G4530_126.103_126.173
#    short cut (100.0 ms): ROG-Art_Rog-Art-J-Gvecg-P580003_Artur-J-G4530_127.123_127.223
#    short cut (60.0 ms): ROG-Art_Rog-Art-J-Gvecg-P580003_Artur-J-G4530_127.543_127.603
#    short cut (90.0 ms): ROG-Art_Rog-Art-J-Gvecg-P580003_Artur-J-G4530_131.713_131.803
#    short cut (70.0 ms): ROG-Art_Rog-Art-J-Gvecg-P580003_Artur-J-G4530_139.573_139.643
#    short cut (80.0 ms): ROG-Art_Rog-Art-J-Gvecg-P580003_Artur-J-G4530_139.923_140.003
#    short cut (90.0 ms): ROG-Art_Rog-Art-J-Gvecg-P580003_Artur-J-G4530_143.023_143.113
#    short cut (100.0 ms): ROG-Art_Rog-Art-J-Gvecg-P580003_Artur-J-G4530_143.853_143.953
#    short cut (100.0 ms): ROG-Art_Rog-Art-J-Gvecg-P580003_Artur-J-G4530_148.472_148.572
#    short cut (80.0 ms): ROG-Art_Rog-Art-J-Gvecg-P580003_Artur-J-G4530_148.842_148.922
#    short cut (80.0 ms): ROG-Art_Rog-Art-J-Gvecg-P580003_Artur-J-G4530_148.922_149.002
#    short cut (70.0 ms): ROG-Art_Rog-Art-J-Gvecg-P580003_Artur-J-G4530_149.622_149.692
#    short cut (80.0 ms): ROG-Art_Rog-Art-J-Gvecg-P580003_Artur-J-G4530_149.692_149.772
#    short cut (80.0 ms): ROG-Art_Rog-Art-J-Gvecg-P580003_Artur-J-G4530_151.242_151.322
#    short cut (100.0 ms): ROG-Art_Rog-Art-J-Gvecg-P580003_Artur-J-G4530_156.211_156.311
#    short cut (100.0 ms): ROG-Art_Rog-Art-J-Gvecg-P580003_Artur-J-G4530_168.174_168.274
#    short cut (100.0 ms): ROG-Art_Rog-Art-J-Gvecg-P580003_Artur-J-G4530_173.167_173.267
#    short cut (80.0 ms): ROG-Art_Rog-Art-J-Gvecg-P580003_Artur-J-G4530_174.655_174.735
#    short cut (90.0 ms): ROG-Art_Rog-Art-J-Gvecg-P580003_Artur-J-G4530_193.086_193.176
#    short cut (92.0 ms): ROG-Art_Rog-Art-J-Gvecg-P580003_Artur-J-G4530_207.100_207.192
#    short cut (100.0 ms): ROG-Art_Rog-Art-J-Gvecg-P580003_Artur-J-G4530_224.452_224.552
#    short cut (90.0 ms): ROG-Art_Rog-Art-J-Gvecg-P580003_Artur-J-G4530_228.336_228.426
#    short cut (80.0 ms): ROG-Art_Rog-Art-J-Gvecg-P580003_Artur-J-G4530_228.426_228.506
#    short cut (100.0 ms): ROG-Art_Rog-Art-J-Gvecg-P580003_Artur-J-G4530_259.684_259.784
#    short cut (70.0 ms): ROG-Art_Rog-Art-J-Gvecg-P580003_Artur-J-G4530_259.784_259.854
#    short cut (60.0 ms): ROG-Art_Rog-Art-J-Gvecg-P580003_Artur-J-G4530_266.110_266.170
#    short cut (90.0 ms): ROG-Art_Rog-Art-J-Gvecg-P580003_Artur-J-G4530_267.503_267.593
#    short cut (90.0 ms): ROG-Art_Rog-Art-J-Gvecg-P580003_Artur-J-G4530_267.863_267.953
#    short cut (60.0 ms): ROG-Art_Rog-Art-J-Gvecg-P580003_Artur-J-G4530_271.389_271.449
#    short cut (90.0 ms): ROG-Art_Rog-Art-J-Gvecg-P580003_Artur-J-G4530_277.301_277.391
#    short cut (60.0 ms): ROG-Art_Rog-Art-J-Gvecg-P580003_Artur-J-G4530_280.331_280.391
#    short cut (100.0 ms): ROG-Art_Rog-Art-J-Gvecg-P580003_Artur-J-G4530_281.543_281.643
#    short cut (90.0 ms): ROG-Art_Rog-Art-J-Gvecg-P580003_Artur-J-G4530_284.052_284.142
#    short cut (90.0 ms): ROG-Art_Rog-Art-J-Gvecg-P580003_Artur-J-G4530_286.200_286.290
#    short cut (70.0 ms): ROG-Art_Rog-Art-J-Gvecg-P580003_Artur-J-G4530_317.597_317.667
# ...
#    short cut (65.0 ms): ROG-Art_Rog-Art-P-G7036-P701111_Artur-P-G7036_85.327_85.392
#    short cut (70.0 ms): ROG-Art_Rog-Art-P-G7036-P701111_Artur-P-G7036_87.872_87.942
#    short cut (60.0 ms): ROG-Art_Rog-Art-P-G7036-P701111_Artur-P-G7036_90.364_90.424
#    short cut (90.0 ms): ROG-Art_Rog-Art-P-G7036-P701111_Artur-P-G7036_97.421_97.511
#    short cut (70.0 ms): ROG-Art_Rog-Art-P-G7036-P701111_Artur-P-G7036_113.602_113.672
#    short cut (60.0 ms): ROG-Art_Rog-Art-P-G7036-P701111_Artur-P-G7036_118.436_118.496
#    short cut (100.0 ms): ROG-Art_Rog-Art-P-G7036-P701111_Artur-P-G7036_131.702_131.802
#    short cut (70.0 ms): ROG-Art_Rog-Art-P-G7036-P701111_Artur-P-G7036_138.729_138.799
#    short cut (60.0 ms): ROG-Art_Rog-Art-P-G7036-P701111_Artur-P-G7036_148.736_148.796
#    short cut (70.0 ms): ROG-Art_Rog-Art-P-G7036-P701111_Artur-P-G7036_161.109_161.179
#    short cut (80.0 ms): ROG-Art_Rog-Art-P-G7036-P701111_Artur-P-G7036_165.422_165.502
#    short cut (100.0 ms): ROG-Art_Rog-Art-P-G7036-P701111_Artur-P-G7036_175.607_175.707
#    short cut (90.0 ms): ROG-Art_Rog-Art-P-G7036-P701111_Artur-P-G7036_180.262_180.352
#    short cut (60.0 ms): ROG-Art_Rog-Art-P-G7036-P701111_Artur-P-G7036_181.702_181.762
#    short cut (70.0 ms): ROG-Art_Rog-Art-P-G7036-P701111_Artur-P-G7036_211.278_211.348
#    short cut (90.0 ms): ROG-Art_Rog-Art-P-G7036-P701111_Artur-P-G7036_216.098_216.188
#    short cut (90.0 ms): ROG-Art_Rog-Art-P-G7036-P701111_Artur-P-G7036_216.978_217.068
#    short cut (80.0 ms): ROG-Art_Rog-Art-P-G7036-P701111_Artur-P-G7036_219.144_219.224
#    short cut (60.0 ms): ROG-Art_Rog-Art-P-G7036-P701111_Artur-P-G7036_229.437_229.497
#    short cut (80.0 ms): ROG-Art_Rog-Art-P-G7036-P701111_Artur-P-G7036_232.667_232.747
#    short cut (90.0 ms): ROG-Art_Rog-Art-P-G7036-P701111_Artur-P-G7036_233.797_233.887
#    short cut (60.0 ms): ROG-Art_Rog-Art-P-G7036-P701111_Artur-P-G7036_234.882_234.942
#    short cut (60.0 ms): ROG-Art_Rog-Art-P-G7036-P701111_Artur-P-G7036_237.128_237.188
#    short cut (90.0 ms): ROG-Art_Rog-Art-P-G7036-P701111_Artur-P-G7036_246.460_246.550
#    short cut (80.0 ms): ROG-Art_Rog-Art-P-G7036-P701111_Artur-P-G7036_253.604_253.684
#    short cut (80.0 ms): ROG-Art_Rog-Art-P-G7036-P701111_Artur-P-G7036_273.242_273.322
#    short cut (63.0 ms): ROG-Art_Rog-Art-P-G7036-P701111_Artur-P-G7036_284.467_284.530
#    short cut (70.0 ms): ROG-Art_Rog-Art-P-G7036-P701111_Artur-P-G7036_290.770_290.840
#    short cut (60.0 ms): ROG-Art_Rog-Art-P-G7036-P701111_Artur-P-G7036_290.840_290.900
#    short cut (80.0 ms): ROG-Art_Rog-Art-P-G7036-P701111_Artur-P-G7036_295.911_295.991
#    short cut (70.0 ms): ROG-Art_Rog-Art-P-G7036-P701111_Artur-P-G7036_297.021_297.091
#    short cut (74.0 ms): ROG-Art_Rog-Art-P-G7036-P701111_Artur-P-G7036_302.353_302.427
#    short cut (100.0 ms): ROG-Art_Rog-Art-P-G7036-P701111_Artur-P-G7036_307.547_307.647
#    short cut (70.0 ms): ROG-Art_Rog-Art-P-G7065-P701064_Artur-P-G7065_10.478_10.548
#    short cut (60.0 ms): ROG-Art_Rog-Art-P-G7065-P701064_Artur-P-G7065_12.502_12.562
#    short cut (96.0 ms): ROG-Art_Rog-Art-P-G7065-P701064_Artur-P-G7065_18.540_18.636
#    short cut (80.0 ms): ROG-Art_Rog-Art-P-G7065-P701064_Artur-P-G7065_20.071_20.151
#    short cut (60.0 ms): ROG-Art_Rog-Art-P-G7065-P701064_Artur-P-G7065_28.703_28.763
#    short cut (60.0 ms): ROG-Art_Rog-Art-P-G7065-P701064_Artur-P-G7065_28.763_28.823
#    short cut (99.0 ms): ROG-Art_Rog-Art-P-G7065-P701064_Artur-P-G7065_39.133_39.232
#    short cut (70.0 ms): ROG-Art_Rog-Art-P-G7065-P701064_Artur-P-G7065_47.206_47.276
#    short cut (90.0 ms): ROG-Art_Rog-Art-P-G7065-P701064_Artur-P-G7065_57.273_57.363
#    short cut (80.0 ms): ROG-Art_Rog-Art-P-G7065-P701064_Artur-P-G7065_69.123_69.203
#    short cut (60.0 ms): ROG-Art_Rog-Art-P-G7065-P701064_Artur-P-G7065_71.363_71.423
#    short cut (60.0 ms): ROG-Art_Rog-Art-P-G7065-P701064_Artur-P-G7065_75.023_75.083
#    short cut (100.0 ms): ROG-Art_Rog-Art-P-G7065-P701064_Artur-P-G7065_81.125_81.225
#    short cut (80.0 ms): ROG-Art_Rog-Art-P-G7065-P701064_Artur-P-G7065_84.077_84.157
#    short cut (100.0 ms): ROG-Art_Rog-Art-P-G7065-P701064_Artur-P-G7065_91.578_91.678
#    short cut (60.0 ms): ROG-Art_Rog-Art-P-G7065-P701064_Artur-P-G7065_94.308_94.368
#    short cut (60.0 ms): ROG-Art_Rog-Art-P-G7065-P701064_Artur-P-G7065_94.368_94.428
#    short cut (80.0 ms): ROG-Art_Rog-Art-P-G7065-P701064_Artur-P-G7065_108.449_108.529
#    short cut (80.0 ms): ROG-Art_Rog-Art-P-G7065-P701064_Artur-P-G7065_108.529_108.609
#    short cut (70.0 ms): ROG-Art_Rog-Art-P-G7065-P701064_Artur-P-G7065_111.638_111.708
#    short cut (90.0 ms): ROG-Art_Rog-Art-P-G7065-P701064_Artur-P-G7065_115.535_115.625
#    short cut (70.0 ms): ROG-Art_Rog-Art-P-G7065-P701064_Artur-P-G7065_118.095_118.165
#    short cut (90.0 ms): ROG-Art_Rog-Art-P-G7065-P701064_Artur-P-G7065_120.225_120.315
#    short cut (90.0 ms): ROG-Art_Rog-Art-P-G7065-P701064_Artur-P-G7065_138.247_138.337
#    short cut (90.0 ms): ROG-Art_Rog-Art-P-G7065-P701064_Artur-P-G7065_153.720_153.810
#    short cut (100.0 ms): ROG-Art_Rog-Art-P-G7065-P701064_Artur-P-G7065_153.810_153.910
#    short cut (90.0 ms): ROG-Art_Rog-Art-P-G7065-P701064_Artur-P-G7065_166.913_167.003
#    short cut (100.0 ms): ROG-Art_Rog-Art-P-G7065-P701064_Artur-P-G7065_171.687_171.787
#    short cut (90.0 ms): ROG-Art_Rog-Art-P-G7065-P701064_Artur-P-G7065_172.906_172.996
#    short cut (90.0 ms): ROG-Art_Rog-Art-P-G7065-P701064_Artur-P-G7065_176.489_176.579
#    short cut (70.0 ms): ROG-Art_Rog-Art-P-G7065-P701064_Artur-P-G7065_186.366_186.436
#    short cut (80.0 ms): ROG-Art_Rog-Art-P-G7065-P701064_Artur-P-G7065_191.868_191.948
#    short cut (60.0 ms): ROG-Art_Rog-Art-P-G7065-P701064_Artur-P-G7065_198.776_198.836
#    short cut (90.0 ms): ROG-Art_Rog-Art-P-G7065-P701064_Artur-P-G7065_203.040_203.130
#    short cut (80.0 ms): ROG-Art_Rog-Art-P-G7065-P701064_Artur-P-G7065_203.290_203.370
#    short cut (72.0 ms): ROG-Art_Rog-Art-P-G7065-P701064_Artur-P-G7065_213.980_214.052
#    short cut (60.0 ms): ROG-Art_Rog-Art-P-G7065-P701064_Artur-P-G7065_220.684_220.744
#    short cut (70.0 ms): ROG-Art_Rog-Art-P-G7065-P701064_Artur-P-G7065_224.584_224.654
#    short cut (60.0 ms): ROG-Art_Rog-Art-P-G7065-P701064_Artur-P-G7065_226.052_226.112
#    short cut (70.0 ms): ROG-Art_Rog-Art-P-G7065-P701064_Artur-P-G7065_228.977_229.047
#    short cut (60.0 ms): ROG-Art_Rog-Art-P-G7065-P701064_Artur-P-G7065_229.047_229.107
#    short cut (90.0 ms): ROG-Art_Rog-Art-P-G7065-P701064_Artur-P-G7065_230.987_231.077
#    short cut (98.0 ms): ROG-Art_Rog-Art-P-G7065-P701064_Artur-P-G7065_232.207_232.305
#    short cut (70.0 ms): ROG-Art_Rog-Art-P-G7065-P701064_Artur-P-G7065_232.515_232.585
#    short cut (70.0 ms): ROG-Art_Rog-Art-P-G7065-P701064_Artur-P-G7065_234.967_235.037
#    short cut (93.0 ms): ROG-Art_Rog-Art-P-G7065-P701064_Artur-P-G7065_238.410_238.503
#    short cut (90.0 ms): ROG-Art_Rog-Art-P-G7065-P701064_Artur-P-G7065_240.285_240.375
#    short cut (80.0 ms): ROG-Art_Rog-Art-P-G7065-P701064_Artur-P-G7065_243.856_243.936
#    short cut (80.0 ms): ROG-Art_Rog-Art-P-G7065-P701064_Artur-P-G7065_246.553_246.633
#    short cut (84.0 ms): ROG-Art_Rog-Art-P-G7065-P701064_Artur-P-G7065_248.547_248.631
#    short cut (62.0 ms): ROG-Art_Rog-Art-P-G7065-P701064_Artur-P-G7065_250.127_250.189
#    short cut (70.0 ms): ROG-Art_Rog-Art-P-G7065-P701064_Artur-P-G7065_250.189_250.259
#    short cut (60.0 ms): ROG-Art_Rog-Art-P-G7065-P701064_Artur-P-G7065_250.259_250.319
#    short cut (60.0 ms): ROG-Art_Rog-Art-P-G7065-P701064_Artur-P-G7065_253.154_253.214
#    short cut (60.0 ms): ROG-Art_Rog-Art-P-G7065-P701064_Artur-P-G7065_267.930_267.990
#    short cut (60.0 ms): ROG-Art_Rog-Art-P-G7065-P701064_Artur-P-G7065_268.300_268.360
#    short cut (100.0 ms): ROG-Art_Rog-Art-P-G7065-P701064_Artur-P-G7065_272.095_272.195
#    short cut (70.0 ms): ROG-Art_Rog-Art-P-G7065-P701064_Artur-P-G7065_275.758_275.828
#    short cut (90.0 ms): ROG-Art_Rog-Art-P-G7065-P701064_Artur-P-G7065_284.015_284.105
#    short cut (60.0 ms): ROG-Art_Rog-Art-P-G7065-P701064_Artur-P-G7065_291.953_292.013
#    short cut (70.0 ms): ROG-Art_Rog-Art-P-G7065-P701064_Artur-P-G7065_297.173_297.243
#    short cut (90.0 ms): ROG-Art_Rog-Art-P-G7065-P701064_Artur-P-G7065_297.243_297.333
#    short cut (70.0 ms): ROG-Art_Rog-Art-P-G7065-P701064_Artur-P-G7065_299.757_299.827
#    short cut (90.0 ms): ROG-Art_Rog-Art-P-G7065-P701064_Artur-P-G7065_301.844_301.934
#    short cut (60.0 ms): ROG-Art_Rog-Art-P-G7065-P701064_Artur-P-G7065_303.451_303.511
#    short cut (40.0 ms): ROG-Art_Rog-Art-P-G7065-P701064_Artur-P-G7065_306.176_306.216
#    short cut (70.0 ms): ROG-Art_Rog-Art-P-G7065-P701064_Artur-P-G7065_309.972_310.042
#    short cut (90.0 ms): ROG-Art_Rog-Art-P-G7155-P700259_Artur-P-G7155_24.432_24.522
#    short cut (80.0 ms): ROG-Art_Rog-Art-P-G7155-P700259_Artur-P-G7155_26.528_26.608
#    short cut (80.0 ms): ROG-Art_Rog-Art-P-G7155-P700259_Artur-P-G7155_31.696_31.776
#    short cut (80.0 ms): ROG-Art_Rog-Art-P-G7155-P700259_Artur-P-G7155_62.728_62.808
#    short cut (70.0 ms): ROG-Art_Rog-Art-P-G7155-P700259_Artur-P-G7155_106.596_106.666
#    short cut (70.0 ms): ROG-Art_Rog-Art-P-G7155-P700259_Artur-P-G7155_117.179_117.249
#    short cut (100.0 ms): ROG-Art_Rog-Art-P-G7155-P700259_Artur-P-G7155_137.799_137.899
#    short cut (100.0 ms): ROG-Art_Rog-Art-P-G7155-P700259_Artur-P-G7155_155.234_155.334
#    short cut (100.0 ms): ROG-Art_Rog-Art-P-G7155-P700259_Artur-P-G7155_165.108_165.208
#    short cut (100.0 ms): ROG-Art_Rog-Art-P-G7155-P700259_Artur-P-G7155_181.703_181.803
#    short cut (60.0 ms): ROG-Art_Rog-Art-P-G7155-P700259_Artur-P-G7155_190.562_190.622
#    short cut (100.0 ms): ROG-Art_Rog-Art-P-G7155-P700259_Artur-P-G7155_199.360_199.460
#    short cut (70.0 ms): ROG-Art_Rog-Art-P-G7155-P700259_Artur-P-G7155_222.061_222.131
#    short cut (60.0 ms): ROG-Art_Rog-Art-P-G7155-P700259_Artur-P-G7155_225.736_225.796
#    short cut (100.0 ms): ROG-Art_Rog-Art-P-G7155-P700259_Artur-P-G7155_241.335_241.435
#    short cut (100.0 ms): ROG-Art_Rog-Art-P-G7155-P700259_Artur-P-G7155_250.781_250.881
#    short cut (90.0 ms): ROG-Art_Rog-Art-P-G7155-P700259_Artur-P-G7155_263.097_263.187
#    short cut (80.0 ms): ROG-Art_Rog-Art-P-G7155-P700259_Artur-P-G7155_271.840_271.920
#    short cut (80.0 ms): ROG-Art_Rog-Art-P-G7155-P700259_Artur-P-G7155_316.299_316.379
#    short cut (100.0 ms): ROG-Art_Rog-Art-P-G7155-P700259_Artur-P-G7155_321.884_321.984
#    short cut (90.0 ms): ROG-Art_Rog-Art-P-G7155-P700259_Artur-P-G7155_326.749_326.839
#    short cut (100.0 ms): ROG-Art_Rog-Art-P-G7155-P700259_Artur-P-G7155_327.309_327.409
#    short cut (90.0 ms): ROG-Art_Rog-Art-P-G7155-P700259_Artur-P-G7155_339.816_339.906
#    short cut (100.0 ms): ROG-Art_Rog-Art-P-G7155-P700259_Artur-P-G7155_339.906_340.006
#    short cut (90.0 ms): ROG-Art_Rog-Art-P-G7155-P700259_Artur-P-G7155_341.226_341.316
#    short cut (90.0 ms): ROG-Art_Rog-Art-P-G7155-P700259_Artur-P-G7155_341.316_341.406
#    short cut (90.0 ms): ROG-Art_Rog-Art-P-G7155-P700259_Artur-P-G7155_344.667_344.757
#    short cut (90.0 ms): ROG-Art_Rog-Art-P-G7155-P700259_Artur-P-G7155_351.442_351.532
#    short cut (100.0 ms): ROG-Art_Rog-Art-P-G7155-P700259_Artur-P-G7155_362.014_362.114
#    short cut (90.0 ms): ROG-Art_Rog-Art-P-G7155-P700259_Artur-P-G7155_366.958_367.048
#    short cut (80.0 ms): ROG-Art_Rog-Art-P-G7165-P700926_Artur-P-G7165_15.118_15.198
#    short cut (70.0 ms): ROG-Art_Rog-Art-P-G7165-P700926_Artur-P-G7165_20.050_20.120
#    short cut (90.0 ms): ROG-Art_Rog-Art-P-G7165-P700926_Artur-P-G7165_34.061_34.151
#    short cut (60.0 ms): ROG-Art_Rog-Art-P-G7165-P700926_Artur-P-G7165_39.880_39.940
#    short cut (90.0 ms): ROG-Art_Rog-Art-P-G7165-P700926_Artur-P-G7165_45.829_45.919
#    short cut (70.0 ms): ROG-Art_Rog-Art-P-G7165-P700926_Artur-P-G7165_45.919_45.989
#    short cut (70.0 ms): ROG-Art_Rog-Art-P-G7165-P700926_Artur-P-G7165_47.472_47.542
#    short cut (80.0 ms): ROG-Art_Rog-Art-P-G7165-P700926_Artur-P-G7165_62.568_62.648
#    short cut (60.0 ms): ROG-Art_Rog-Art-P-G7165-P700926_Artur-P-G7165_64.758_64.818
#    short cut (100.0 ms): ROG-Art_Rog-Art-P-G7165-P700926_Artur-P-G7165_84.733_84.833
#    short cut (60.0 ms): ROG-Art_Rog-Art-P-G7165-P700926_Artur-P-G7165_89.889_89.949
#    short cut (90.0 ms): ROG-Art_Rog-Art-P-G7165-P700926_Artur-P-G7165_122.835_122.925
#    short cut (70.0 ms): ROG-Art_Rog-Art-P-G7165-P700926_Artur-P-G7165_122.925_122.995
#    short cut (70.0 ms): ROG-Art_Rog-Art-P-G7165-P700926_Artur-P-G7165_122.995_123.065
#    short cut (70.0 ms): ROG-Art_Rog-Art-P-G7165-P700926_Artur-P-G7165_133.493_133.563
#    short cut (80.0 ms): ROG-Art_Rog-Art-P-G7165-P700926_Artur-P-G7165_138.940_139.020
#    short cut (80.0 ms): ROG-Art_Rog-Art-P-G7165-P700926_Artur-P-G7165_150.860_150.940
#    short cut (90.0 ms): ROG-Art_Rog-Art-P-G7165-P700926_Artur-P-G7165_152.969_153.059
#    short cut (100.0 ms): ROG-Art_Rog-Art-P-G7165-P700926_Artur-P-G7165_169.568_169.668
#    short cut (100.0 ms): ROG-Art_Rog-Art-P-G7165-P700926_Artur-P-G7165_183.171_183.271
#    short cut (60.0 ms): ROG-Art_Rog-Art-P-G7165-P700926_Artur-P-G7165_183.391_183.451
#    short cut (80.0 ms): ROG-Art_Rog-Art-P-G7165-P700926_Artur-P-G7165_183.791_183.871
#    short cut (90.0 ms): ROG-Art_Rog-Art-P-G7165-P700926_Artur-P-G7165_190.510_190.600
#    short cut (60.0 ms): ROG-Art_Rog-Art-P-G7165-P700926_Artur-P-G7165_204.886_204.946
#    short cut (60.0 ms): ROG-Art_Rog-Art-P-G7165-P700926_Artur-P-G7165_204.946_205.006
#    short cut (91.0 ms): ROG-Art_Rog-Art-P-G7165-P700926_Artur-P-G7165_209.760_209.851
#    short cut (60.0 ms): ROG-Art_Rog-Art-P-G7165-P700926_Artur-P-G7165_213.173_213.233
#    short cut (70.0 ms): ROG-Art_Rog-Art-P-G7165-P700926_Artur-P-G7165_222.625_222.695
#    short cut (100.0 ms): ROG-Art_Rog-Art-P-G7165-P700926_Artur-P-G7165_223.395_223.495
#    short cut (100.0 ms): ROG-Art_Rog-Art-P-G7165-P700926_Artur-P-G7165_223.495_223.595
#    short cut (100.0 ms): ROG-Art_Rog-Art-P-G7165-P700926_Artur-P-G7165_223.595_223.695
#    short cut (90.0 ms): ROG-Art_Rog-Art-P-G7165-P700926_Artur-P-G7165_233.833_233.923
#    short cut (100.0 ms): ROG-Art_Rog-Art-P-G7165-P700926_Artur-P-G7165_240.074_240.174
#    short cut (74.0 ms): ROG-Art_Rog-Art-P-G7165-P700926_Artur-P-G7165_244.253_244.327
#    short cut (90.0 ms): ROG-Art_Rog-Art-P-G7165-P700926_Artur-P-G7165_257.007_257.097
#    short cut (90.0 ms): ROG-Art_Rog-Art-P-G7165-P700926_Artur-P-G7165_260.532_260.622
#    short cut (60.0 ms): ROG-Art_Rog-Art-P-G7165-P700926_Artur-P-G7165_261.687_261.747
#    short cut (70.0 ms): ROG-Art_Rog-Art-P-G7165-P700926_Artur-P-G7165_261.747_261.817
#    short cut (90.0 ms): ROG-Art_Rog-Art-P-G7165-P700926_Artur-P-G7165_263.865_263.955
#    short cut (90.0 ms): ROG-Art_Rog-Art-P-G7165-P700926_Artur-P-G7165_275.576_275.666
#    short cut (60.0 ms): ROG-Art_Rog-Art-P-G7165-P700926_Artur-P-G7165_277.612_277.672
#    short cut (60.0 ms): ROG-Art_Rog-Art-P-G7165-P700926_Artur-P-G7165_292.463_292.523
#    short cut (60.0 ms): ROG-Art_Rog-Art-P-G7165-P700926_Artur-P-G7165_297.198_297.258
#    short cut (70.0 ms): ROG-Art_Rog-Art-P-G7165-P700926_Artur-P-G7165_306.981_307.051
#    short cut (60.0 ms): ROG-Art_Rog-Art-P-G7165-P700926_Artur-P-G7165_310.514_310.574
#    short cut (70.0 ms): ROG-Art_Rog-Art-P-G7165-P700926_Artur-P-G7165_311.874_311.944
#    short cut (90.0 ms): ROG-Art_Rog-Art-P-G7165-P700926_Artur-P-G7165_314.324_314.414
#    short cut (80.0 ms): ROG-Art_Rog-Art-P-G7165-P700926_Artur-P-G7165_330.024_330.104
#    short cut (60.0 ms): ROG-Art_Rog-Art-P-G7165-P700926_Artur-P-G7165_330.104_330.164
#    short cut (90.0 ms): ROG-Art_Rog-Art-P-G7165-P700926_Artur-P-G7165_331.354_331.444
#    short cut (60.0 ms): ROG-Art_Rog-Art-P-G7165-P700926_Artur-P-G7165_331.444_331.504
#    short cut (60.0 ms): ROG-Art_Rog-Art-P-G7165-P700926_Artur-P-G7165_345.086_345.146
#    short cut (80.0 ms): ROG-Art_Rog-Art-P-G7165-P700926_Artur-P-G7165_345.766_345.846
#
# ----------------------------------------------------------------------
# Stats
# ----------------------------------------------------------------------
#                input: 37036
#       missing_source: 0
#           cut_failed: 14
#     skipped_existing: 0
#                 kept: 37022
#         short_warned: 1770

# %% [markdown]
# ---
#
# ## 8. Write the output JSONL and re-validate
#
# Test mode mirrors the output path under `data/test_processed_jsonl/` so it can't overwrite real outputs.

# %%
out_path = (cfg.output_jsonl
            if not cfg.test_mode
            else cfg.output_jsonl.replace("data/processed_jsonl/", "data/test_processed_jsonl/"))
n_written = udp.write_jsonl(kept, out_path)
print(f"✅ wrote {n_written} records to {out_path}")

n_total, n_valid, errs = udp.validate_jsonl(udp.iter_jsonl(out_path))
if errs:
    print(f"⚠️  output has {n_total - n_valid}/{n_total} invalid records:")
    for e in errs[:5]:
        print(f"   {e}")
else:
    print(f"✅ output validates: {n_valid}/{n_total}")
# Out:
# ✅ wrote 37022 records to data/processed_jsonl/rog_instance.jsonl
# ✅ output validates: 37022/37022

# %% [markdown]
# ---
#
# ## 9. Spot-check a cut WAV
#
# Open one of the freshly cut files and confirm the duration matches `end_t - start_t` within a few ms, and the sample rate is 16 kHz.

# %%
if kept:
    r = kept[0]
    p = udp.from_project_relative(r["audio_path"])
    data, sr = sf.read(str(p))
    dur_actual = len(data) / sr
    if "start_t" in r and "end_t" in r:
        dur_expected = r["end_t"] - r["start_t"]
        print(f"{r['instance_id']}")
        print(f"   sr={sr}, actual={dur_actual:.4f}s, expected={dur_expected:.4f}s, "
              f"delta={1000*(dur_actual - dur_expected):.2f}ms")
    else:
        print(f"{r['instance_id']}: whole-file, sr={sr}, duration={dur_actual:.4f}s")
else:
    print("No records were kept — nothing to spot-check.")
# Out:
# ROG-Art_Rog-Art-J-Gvecg-P500001_Artur-J-G3003_2082.198_2082.453
#    sr=16000, actual=0.2551s, expected=0.2550s, delta=0.06ms

# %% [markdown]
# ---
#
# ## 10. What's next
#
# Chapter 1 is now complete for this dataset. The next chapter is **`2_data_analysis/sniff_dataset.ipynb`** — point it at the JSONL we just wrote (e.g. `data/processed_jsonl/rog_dialog_instance.jsonl`) and look at label distributions, audio-duration histograms, and per-split summaries before touching a model.
